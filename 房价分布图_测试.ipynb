# %%
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from matplotlib.font_manager import FontProperties
from pylab import *
matplotlib.rcParams['font.sans-serif'] = ['Arial Unicode MS']
import matplotlib  # 导入matplotlib库，使用matplotlib提供的rc()方法进行字体的设置
font = {'family': 'Microsoft YaHei',  'weight': 'bold',  'size': '14'}
matplotlib.rc("font", family="Microsoft YaHei", weight="bold", size="14")

# %%
df = pd.read_excel('/Users/19723/Desktop/TES.xlsx')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5882 entries, 0 to 5881
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   City      5882 non-null   object
#  1   Estate    5882 non-null   object
#  2   Prc       5882 non-null   int64
#  3   totalprc  5882 non-null   float64
#  4   Strict    5882 non-null   object
#  5   Type      5882 non-null   object
#  6   area      5882 non-null   float64
#  7   Year      5696 non-null   object
#  8   rooms     5882 non-null   object
#  9   Time      5882 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 459.7+ KB
#      City    Estate    Prc  totalprc Strict  Type   area    Year rooms  \
# 0      上海      海尚康庭  44017     430.0     浦东    板楼  97.69  2008年建    平层
# 1      上海    爱庐世纪新苑  52650     457.0     闵行    板楼  86.80  2007年建    平层
# 2      上海      东都小区  39601     230.0     浦东    板楼  58.08  1983年建    平层
# 3      上海      弘丰新苑  77945     775.0     虹口    板楼  99.43  1997年建    平层
# 4      上海      民星二村  55438     235.0     杨浦    板楼  42.39  1995年建    平层
# ...   ...       ...    ...       ...    ...   ...    ...     ...   ...
# 5877   北京    保利西山林语  75067     367.0     海淀  板塔结合  48.89  2010年建    平层
# 5878   北京      京贸家园  49070     435.0     通州  板塔结合  88.65  2010年建    平层
# 5879   北京  龙湖香醍漫步一区  38667     355.0     顺义    板楼  91.81  2008年建    平层
# 5880   北京      卢西嘉园  37380     210.0     丰台    板楼  56.18  2007年建    平层
# 5881   北京       富卓苑  64378     448.0     丰台    板楼  69.59  2000年建    平层
#
#                                                    Time
# 0     2013年12月09日\n                                 ...
# 1     2009年12月31日\n                                 ...
# 2     1999年08月09日\n                                 ...
# 3     2000年04月25日\n                                 ...
# 4     2014年06月10日\n                                 ...
# ...                                                 ...
# 5877  2016年04月01日\n                                 ...
# 5878  2012年09月03日\n                                 ...
# 5879  2013年11月01日\n                                 ...
# 5880  2015年12月28日\n                                 ...
# 5881  2016年04月18日\n                                 ...
#
# [5882 rows x 10 columns]

# %%
zhongguo = matplotlib.font_manager.FontProperties(fname="/Users/19723/Desktop/API/字体/SourceHanSansSC-Bold.otf") 
# plt.figure(figsize=(12, 6))
# df.总价.plot(kind="hist", ax=ax)
fig, ax = plt.subplots(1, 3, figsize=(20, 9))

# bin_edges = np.arange(0, df['totalprc'].max()+1, 15)
# ax[0].hist(data=df, x='总价', bins=bin_edges, color="#A5C8E1")
# xticks = np.arange(0, df.totalprc.max()+5, 100)
# ax[0].set_xticks(ticks=xticks)
# ax[0].set_xticklabels(labels=["%d" % i for i in xticks])
# ax[0].set_xlabel("总价(万元)", fontsize=15, fontproperties=zhongguo)
# ax[0].set_title("在售二手房价格分布", fontsize=20, fontproperties=zhongguo)

sns.distplot(df.totalprc, ax=ax[0])
ax[0].set_xlabel("总价(万元)", fontsize=15, fontproperties=zhongguo)
ax[0].set_title("在售二手房价格分布", fontsize=20, fontproperties=zhongguo)
xticks = np.arange(0, df.totalprc.max()+500, 1000)
ax[0].set_xticks(ticks=xticks)
ax[0].set_xticklabels(labels=["%d" % i for i in xticks])

# 面积
sns.distplot(df.area, ax=ax[1])
ax[1].set_xlabel("总面积（平方米）", fontsize=15, fontproperties=zhongguo)
ax[1].set_title("在售二手房房屋面积分布", fontsize=20, fontproperties=zhongguo)
xticks = np.arange(0, df.area.max()+50, 50)
ax[1].set_xticks(ticks=xticks)
ax[1].set_xticklabels(labels=["%d" % i for i in xticks])

# 单价
sns.distplot(df.Prc, ax=ax[2])
ax[2].set_xlabel("单价（元/平方米）", fontsize=15, fontproperties=zhongguo)
ax[2].set_title("在售二手房房屋单价分布", fontsize=20, fontproperties=zhongguo)
# xticks = np.arange(0, df.每平米价格.max()+5000, 10000)
# ax[2].set_xticks(ticks=xticks)
# ax[2].set_xticklabels(labels=["%d" % i for i in xticks])
plt.show()

# %%
ax = plt.subplots(2,1, figsize=(30, 20))
df["Strict"].value_counts(dropna=False).plot(kind="bar", ax=ax[1][0], rot=30, color="#A5C8E1", fontsize=12)
ax[1][0].set_yticklabels("")
# ax.set_axis_off()
for index, value in enumerate(df["Strict"].value_counts(dropna=False)):
    ax[1][0].text(x=index-.15, y=value+2, s=value, fontdict={"size": 10}, fontproperties=zhongguo)
ax[1][0].set_title("在售房屋所在城区", fontsize=15, fontproperties=zhongguo)
# ax[1][0].axes.tick_params(labelleft=False, left=False)
plt.xticks(fontproperties=zhongguo)
plt.show()
